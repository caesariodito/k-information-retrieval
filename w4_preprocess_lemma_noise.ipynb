# %% [markdown]
# # Modul 4
# ## Paulus Caesario Dito Putra Hartono
# ## 205314159

# %% [markdown]
# ### 1 importing nltk

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /root/nltk_data...
# ...

# %% [markdown]
# #### Penjelasan
#
# mengimport library nltk dan mendownload beberapa component yang dapat digunakan di library tersebut. Tanpa component tersebut library tidak bisa berjalan secara penuh. Pada baris 2 nltk.download diberi parameter 'all' yang berguna untuk mendownload semua compoent yang diperlukan

# %% [markdown]
# ### 2 Lakukan penghilangan tanpa library pada awalan dan akhiran teks="Pertemanan!

# %%
teks="Pertemanan! DiTemaNkAn3 beRtEman"
kata_dasar = 'teman'

preprocess = teks.lower()
preprocess = preprocess.split()

noise = [x.split(kata_dasar) for x in preprocess]

fix_noise = []

for x in noise:
  if len(x) == 1:
    fix_noise.append(x[0])
  else:
    for xs in x:
      fix_noise.append(xs)

print(teks)
print(fix_noise)

hasil = []

for i in range(len(preprocess)):
  temp = preprocess[i]
  for j in range(len(fix_noise)):
    temp = temp.replace(fix_noise[j], '')
  hasil.append(temp)

hasil
# Out:
# Pertemanan! DiTemaNkAn3 beRtEman
# ['per', 'an!', 'di', 'kan3', 'ber', '']
# ['teman', 'teman', 'teman']

# %% [markdown]
# #### Penjelasan
#
# Algoritma dasar - (baris code):
# 1. menentukan kata dasar dari suatu kata - (2)
# 2. lowercasing teks - (4)
# 3. tokenisasi teks dengan method split() - (5)
# 4. mencari noise dengan menentukan kata dasar yang sudah ada. Hal ini dapat menggunakan str.split() dengan parameter kata dasar - (7)
# 5. Merapihkan format dari noise yang didapat - (11 s.d. 16)
# 6. Lakukan perulangan untuk setiap kata dan replace setiap token yang memiliki noise yang sudah didapat dari proses sebelumnya - (23 s.d. 26)
# 7. Dari filtering di perulangan setiap kata dan remove noise, hasilnya disimpan di dalam variabel yang bernama 'hasil' - (27)
#
# teks awal tertampil pada output baris pertama. <br>
# noise yang sudah dirapihkan dapat terlihat di baris kedua. <br>
# kata - kata yang sudah di-stem dapat dilihat di baris ketiga.

# %% [markdown]
# ### 3 Lakukan proses Lowercasing dengan program dibawah ini dan jelaskan perubahannya!

# %%
teks=["Yogyakarta","YOGYAKARTA","YOGYAkarta","yOgyAkArtA"]
lower_words=[word.lower() for word in teks]
lower_words
# Out:
# ['yogyakarta', 'yogyakarta', 'yogyakarta', 'yogyakarta']

# %% [markdown]
# #### Penjelasan
#
# baris 1: teks awal <br>
# baris 2: lakukan perulangan untuk setiap index di list 'teks' dan lowercase 'teks' dari index tersebut, lakukan juga penyimpanan pada list baru yang bernama 'lower_words' <br>
# baris 3: menampilkan isi dari variabel 'lower_words'

# %% [markdown]
# ### 4  Lakukan proses Stemming dengan program dibawah ini dan jelaskan perubahannya!

# %% [markdown]
# #### a. Import nltk

# %%
import nltk
import pandas as pd
from nltk.stem import PorterStemmer

# %% [markdown]
# #### b. Import Stemmer
#
# membuat stemmer yang nantinya akan digunakan pada bagian selanjutnya.

# %%
porter_stemmer=PorterStemmer()

# %% [markdown]
# #### c. Stemming

# %%
words=["connect","connected","connection","connections","connects","connecting"]
stemmed_words=[porter_stemmer.stem(word=word) for word in words]
stemdf= pd.DataFrame({'original_word': words,'stemmed_word':stemmed_words})
stemdf
# Out:
#   original_word stemmed_word
# 0       connect      connect
# 1     connected      connect
# 2    connection      connect
# 3   connections      connect
# 4      connects      connect
# 5    connecting      connect

# %% [markdown]
# #### Penjelasan
#
# Pada baris 1: dibuat list yang berisi berbagai kata yang bukan merupakan kata dasar. Isi dari list yang berisi kata - kata tersebut akan di-stemming. Proses stemmer dilakukan pada baris 2 dengan menggunakan perulangan yang menghasilkan list baru bernama stemmed_words. Baris 3 dan 4 merupakan perintah untuk membuat datafrmae dengan isi yang dapat dilihat di output.

# %% [markdown]
# ### 5 Lakukan proses Lemmatization dengan program dibawah ini dan jelaskan perbedaan nomor c dan d!

# %% [markdown]
# #### a. Import nltk
#
# Mendownload lib yang dibutuhkan

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# #### b. Import Lemmatizer
# Mengimport lemmatizer untuk melakukan lemmatization

# %%
lemmatizer = WordNetLemmatizer()

# %% [markdown]
# #### c. Lemmatization

# %%
words=["learn","learning","learned","learnt",]
lemmatized_words= [lemmatizer.lemmatize(word=word,pos='v') for word in words]
lemmatizeddf= pd.DataFrame({'original_word': words,'lemmatized_word':lemmatized_words})
lemmatizeddf
# Out:
#   original_word lemmatized_word
# 0         learn           learn
# 1      learning           learn
# 2       learned           learn
# 3        learnt           learn

# %% [markdown]
# #### Penjelasan Lemmatization
#
# Pada baris 1: berisi kata - kata yang akan di-lemmatize.
# Baris 2: merupakan proses lemmatization dengan library yang sudah diimport tadi dengan perulangan.
# Baris 3 dan 4: Merupakan perintah untuk membuat dataframe dan menampilkannya

# %% [markdown]
# ####  d. Plural lemmatization

# %%
words=["goose", "geese"]
lemmatized_words = [lemmatizer.lemmatize(word=word,pos='n') for word in words]
lemmatizeddf= pd.DataFrame({'original_word':words,'lemmatized_word':lemmatized_words})
lemmatizeddf=lemmatizeddf[['original_word','lemmatized_word']]
lemmatizeddf
# Out:
#   original_word lemmatized_word
# 0         goose           goose
# 1         geese           goose

# %% [markdown]
# #### Penjelasan Plural Lemmatization
#
# Pada baris 1: berisi kata - kata yang akan di-lemmatize.
# Baris 2: merupakan proses lemmatization dengan library yang sudah diimport tadi dengan perulangan.
# Baris 3 dan 4: Merupakan perintah untuk membuat dataframe dan menampilkannya
#
# Perbedaan section ini dengan sebelumnya terletak pada parameter lemmatize yang terdapat pada baris 2.

# %% [markdown]
# ### 6 Lakukan proses Stop Word Removal dengan program dibawah ini dan jelaskan cara kerjanya!

# %%
stopwords=["this","that","and","a","we","it","to","is","of","up","need"]
text='this is a text full of content and we need to clean it up'
words=text.split(" ")
shortlisted_words=[]
for x in words:
  if x not in stopwords:
    shortlisted_words.append(x)
  else:
    shortlisted_words.append("X")
print("kalimat asli = ",text)
print("kalimat dengan menghilangkan stop words = ",''.join(shortlisted_words))
# Out:
# kalimat asli =  this is a text full of content and we need to clean it up
# kalimat dengan menghilangkan stop words =  XXXtextfullXcontentXXXXcleanXX

# %% [markdown]
# #### Penjelasan
#
# Baris 1: Merupakan list stopword yang akan digunakan untuk proses stop word removal. <br>
# Baris 2: Merupakan text yang akan dilakukan proses stop word removal. <br>
# Baris 3: Melakukan tokenisasi dengan method split. <br>
# Baris 4: Merupakan list kosong yang akan digunakan untuk menampung hasil text yang sudah di stop word. <br>
# Baris 5 - 9: Perulangan yang digunakan untuk melakukan stop words. 'Jika suatu word x tidak berada pada list stopword, maka dilakukan append/penambahan word tersebut ke dalam list shortlisted_words/hasil. Jika word x tersebut berada di dalam list stopwords, maka akan dilakukan append 'x'. <br>
# Baris 10 dan 11: Merupakan print output untuk menampilkan hasil.

# %% [markdown]
# ### 7 Lakukan proses Noise Removal dengan program dibawah ini dan jelaskan cara kerjanya!

# %% [markdown]
# #### a. Import re

# %%
import re

# %% [markdown]
# #### b. Input data

# %%
raw_words=["..trouble..","trouble<","trouble!","<a>trouble<a>",'1.trouble']

# %% [markdown]
# #### c. Membuat fungsi untuk Noise Removal

# %%
def scrub_words(text):
  # cleaning dasar
  # remove html markup
  text=re.sub("(<.*?>)","",text)
  #remove non-ascii dan digits
  text=re.sub("(\\W|\\d)"," ",text)
  #remove whitespace
  text=text.strip()
  return text

# %% [markdown]
# #### d. Membuat fungsi untuk Noise Removal

# %%
cleaned_words=[scrub_words(w) for w in raw_words]
cleaned_words
# Out:
# ['trouble', 'trouble', 'trouble', 'trouble', 'trouble']

# %% [markdown]
# #### Penjelasan
#
# Melakukan noise removal menggunakan function yang sudah dibuat. Penjelasan dari function dapat terlihat pada comment di bagian c. Proses noise removal dilakukan dengan perulangan dengan isi function dari masing - masing word di dalam raw_words.

# %% [markdown]
# ### 8 Lakukan proses Normalization pada karakter dibawah ini menjadi tulisan (smile, sad, kiss, cry dan love) dan jelaskan cara kerjanya!

# %%
emot1=["':)'","':('","':*'","':'('","'<3'"]
dictEmot1 = {"':)'":'smile',"':('":'sad',"':*'":'kiss',"':'('":'cry',"'<3'":'love'}

# %%
normalization = []

for x in emot1:
  if x in dictEmot1.keys():
    normalization.append(dictEmot1[x])

normalization
# Out:
# ['smile', 'sad', 'kiss', 'cry', 'love']

# %% [markdown]
# #### Penjelasan
#
# Menggunakan dictionary dengan key dan values yang sesuai. Ibaratkan dictionary ini merupakan database yang digunakan untuk mencocokan isi dari emot1. Proses ini mirip seperti stopword removals pada section sebelumnya. Jika suatu kata pada emot1 berada pada dictionary yang ada, maka kita akan melakukan print value dari dictionary dengan key yang sesuai.

# %% [markdown]
# ### 9 Jelaskan teks processing apa saja yang anda dilakukan pada nomor 1!
#
# Sudah dijelaskan pada setiap nomor.

# %% [markdown]
# ### 10 Jalankan program dibawah Jupiter Notebook atau Google Collab menggunakan sastrawi!

# %% [markdown]
# #### a. Install sastrawi

# %%
# !pip install PySastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 210 kB 14.2 MB/s
# ...

# %% [markdown]
# #### b. Impor sastrawi

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %% [markdown]
# #### c. Membuat stemmer

# %%
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %% [markdown]
# #### d. Input data

# %%
teks='Pemrosesan bahasa alami, disingkat PBA atau NLP (natural language processing), adalah cabang ilmu komputer dan linguistik yang mengkaji interaksi antara komputer dengan bahasa (alami) manusia. NLP sering dianggap sebagai cabang dari kecerdasan buatan dan bidang kajiannya bersinggungan dengan linguistik komputasional. Kajian NLP antara lain mencakup segmentasi tuturan (speech segmentation), segmentasi teks (text segmentation), penandaan kelas kata (part-of-speech tagging), serta pengawataksaan makna (word sense disambiguation). Meskipun kajiannya dapat mencakup teks dan tuturan, pemrosesan tuturan (speech processing) telah berkembang menjadi suatu bidang kajian terpisah.'

# %% [markdown]
# #### e. Preprocessing

# %%
tks=stemmer.stem(teks)

# %% [markdown]
# #### f. Jelaskan perubahan yang terjadi di teks ketika menjadi tks

# %% [markdown]
# ### 11 Gunakan data scraping dari modul 2 nomor 10, kemudian lakukan praproses teks menggunakan sastrawi!

# %% [markdown]
# #### Scrap ulang

# %%
# https://jogja.tribunnews.com/2022/09/14/4-rekomendasi-kuliner-bubur-ayam-di-jogja-cocok-buat-menu-sarapan

import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

url = "https://jogja.tribunnews.com/2022/09/14/4-rekomendasi-kuliner-bubur-ayam-di-jogja-cocok-buat-menu-sarapan?page=2"

page=requests.get(url)
soup = bs(page.content, 'html.parser')

head_tag = soup.head

body_tag = soup.body

judul = head_tag.contents[1].contents[0]

# print('Judul: ', judul)

tanggal = body_tag.time.contents[0]

# print('Tgl Penulisan: ', tanggal)

img_thumb = body_tag.find_all('img', class_='imgfull')[0]['src']

# print('Url Thumbnail: ', img_thumb)

strong_str = body_tag.find_all('strong')

bolded_text = []
for x in strong_str:
  bolded_text.append(x.text)


paragraphs = body_tag.find_all('p')

paragraphs_content = []

for p in paragraphs:
  paragraphs_content.append(p.text)

# paragraphs_content

table = pd.DataFrame.from_dict({
  "Judul": judul,
  "Tanggal": tanggal,
  "Thumbnail": img_thumb,
  "Bolded-Tags": bolded_text,
  "Paragraphs": paragraphs_content
}, orient='index')

# table = table.transpose() 

table.to_csv('tribunjogja-onepage.csv')

table
# Out:
#                                                              0
# Judul        4 Rekomendasi Kuliner Jogja Menyantap Bubur Ay...
# Tanggal                      Rabu, 14 September 2022 11:16 WIB
# Thumbnail    https://t-2.tstatic.net/jogja/foto/bank/images...
# Bolded-Tags  [3. Bubur Ayamnya Opa,  Baca juga: 10 Rekomend...
# Paragraphs   [Di burnesia ini Kuliner Jogja dapat menikmati...

# %% [markdown]
# #### Preprocessing Text

# %%
# print(paragraphs_content)

# data teks2
data = paragraphs_content

# import StemmerFactory class
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

factory = StopWordRemoverFactory()
stopwords = factory.get_stop_words()
stopword = factory.create_stop_word_remover()

stemmed_words = []

for p in data:
  stemmed_words.append(stemmer.stem(p))

stemmed_words

preprocessed = []

for sentence in stemmed_words:
  preprocessed.append(stopword.remove(sentence))

preprocessed
# Out:
# ['burnesia kuliner jogja nikmat jenis bubur bubur ayam bubur ketan durian bubur jagung bubur ketan hitam bubur kacang hijau pilih bubur toping ice cream loh',
#  'harga murah jangkau 5k',
#  'lokasi jl gurameh raya no 19a minomartani ngaglik sleman buka jam 06 00 - 21 00',
#  '3 bubur ayam opa',
#  'bubur ayam opa lokasi jl ks tubun 52 tampil jogja outlet pusat cabang jl pintu selatan upn no 7 tur',
#  'ramai unjung spot bubur ayam happening banget milik cita khas unjung nikmat varian menu bubur ayam opa',
#  'aneka menu bubur original bubur cakwe dimsum sate',
#  'buka 06 00 - 20 00 harga jangkau 8k',
#  'baca 10 rekomendasi kuliner malam jogja ramai unjung',
#  '4 bubur hayam kotabaru',
#  'bubur hayam kotabaru nikmat saji bubur varian menu lengkap']

# %% [markdown]
# ### 12 Carilah atau browsing satu berita berbahasa Inggris, simpanlah dalam csv pada satu kolom, kemudian lakukan teks processing menggunakan nltk!
#
# https://www.bbc.com/news/world-asia-62976842

# %% [markdown]
# #### data awal

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

url = "https://www.bbc.com/news/world-asia-62976842"

page=requests.get(url)
soup = bs(page.content, 'html.parser')

body_tag = soup.body

article = body_tag.find('article')

paragraphs = article.find_all(attrs={"data-component": "text-block"})

texts = []

for p in paragraphs:
  texts.append(p.text)

table = pd.DataFrame({
  "text": texts
})

table.to_csv('raw_text.csv')

table
# Out:
#                                                  text
# 0   A Japanese man has set himself alight reported...
# 1   Hundreds of dignitaries from Japan and around ...
# 2   On Wednesday, witnesses called police after sp...
# 3   Officers put out the blaze, and took the still...
# 4   The extent of his injuries and his current con...
# 5   The government is yet to comment on the protes...
# 6   Abe was shot dead on 8 July, aged 67, at a cam...
# 7   But state funerals are not an established prac...
# 8   One of the country's main opposition parties, ...
# 9                              By Mariko Oi, BBC News
# 10  Many in Japan are commenting on how the mood a...
# 11  Surveys show a majority of Japanese are agains...
# 12  Others say that Prime Minister Fumio Kishida i...
# 13  Adding to the sour mood, a film about Abe's mu...
# 14  Police are yet to confirm details about the ma...
# 15  Handwritten notes were also found around the m...
# ...

# %% [markdown]
# #### preprocessing text:

# %%
import pandas as pd
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

def clean_text(text):
  text = text.lower()
  text = re.sub(r"(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", text)
  text = re.sub(r"\d+", "", text)
  return text

ps = PorterStemmer()
stop = stopwords.words('english')

table = pd.read_csv('raw_text.csv')

table['text']

texts = table['text']
preprocessed = []


for t in texts:
  t = t.lower()
  t = clean_text(str(t))
  t = word_tokenize(t)
  t = [ps.stem(w) for w in t]
  t = [w for w in t if not w in stop]
  preprocessed.append(t)


preprocessed

table['preprocessed_text'] = preprocessed

table
# Out:
#     Unnamed: 0                                               text  \
# 0            0  A Japanese man has set himself alight reported...
# 1            1  Hundreds of dignitaries from Japan and around ...
# 2            2  On Wednesday, witnesses called police after sp...
# 3            3  Officers put out the blaze, and took the still...
# 4            4  The extent of his injuries and his current con...
# 5            5  The government is yet to comment on the protes...
# 6            6  Abe was shot dead on 8 July, aged 67, at a cam...
# 7            7  But state funerals are not an established prac...
# 8            8  One of the country's main opposition parties, ...
# 9            9                             By Mariko Oi, BBC News
# 10          10  Many in Japan are commenting on how the mood a...
# 11          11  Surveys show a majority of Japanese are agains...
# 12          12  Others say that Prime Minister Fumio Kishida i...
# ...
